# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import sweetviz as sv

def out(ver,data,sw=False):
    data.to_csv('output/'+ver+'_English_only.csv')
    data.to_pickle('output/'+ver+'_English_only.pickle')
    data.to_excel('output/'+ver+'_English_only.xlsx')
    if sw:
        sv.analyze(data).show_html('output/'+ver+'_English_only.html')

# %%
old = pd.read_pickle('renders/renders_awards_v4_Kaggle_out.pickle')
new = pd.read_pickle('renders/renders_awards_v5_Kaggle_out.pickle')

# %%
old.drop(columns=['index','Unnamed: 0'],inplace=True)
new.drop(columns=['index','Unnamed: 0','Unnamed: 0.1'],inplace=True)

# %%
new.head(3)
# Out:
#                Recipients                                        WikiLink  Padma Shri Year       Padma Shri State          Padma Shri Field Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By                             Born Birth Date Place of Birth Died Death Date Place of Death Nationality Spouse Alma mater Institutions Other Awards including Padma         Occupation Election Year Posthumus     Page Id               image
# ...

# %%
old.head(3)
# Out:
#                Recipients                                            Summary                                             career      references                                         early life                                               life awards freedom fighter death filmography works biography selected publications see also awards and honours teaching philanthropy personal life bibliography early life and education writings legacy discography biographies external links work publications awards and recognitions further reading life and education academic career political views books early life and background acting career television career in the media politics activism early life and career awards and recognition awards and accolades selected works recognition education and career philosophy honours positions held notes posts held later years disciples death and legacy achievements singing career films education contributions early life and family honours and awards  \
# ...

# %%
old.drop(columns=['Recipients Telugu'],inplace=True)

# %%
awards_final = pd.merge(new,old)
awards_final.head(5)
# Out:
#                Recipients                                        WikiLink  Padma Shri Year       Padma Shri State          Padma Shri Field Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By                                               Born                      Birth Date Place of Birth                                               Died                           Death Date            Place of Death Nationality Spouse Alma mater Institutions Other Awards including Padma         Occupation Election Year Posthumus     Page Id                                     image                                            Summary                                             career      references                                         early life                                               life                                             awards  \
# ...

# %%
out('Padma_Awards_Datasets',awards_final)

# %%
d = {}
for i in old.columns:
    if i not in d:
        d[i] = sum(~pd.isna(old[i])) 
k = list(sorted(d.items(), key=lambda x:x[1],reverse=True))
new_lis = [ i[0] for i in k]
old = old[new_lis]
# old.head(4)
new_lis
dont_want = ['Recipients', 'Recipients Telugu','references','see also','external links', 'gallery',]
Final = ['Recipients', 'Recipients Telugu']
for i in new_lis:
    if i not in dont_want:
        print(i)

# from deep_translator import GoogleTranslator

# tel = {}
# for i in new_lis:
#     if i not in dont_want:
#         Final.append(i)
#         Final.append(i+' Telugu')
# d2 = {}
# for i,j in enumerate(old.columns):
#     d2[j] = i
# d2
# Out:
# Summary
# career
# biography
# early life
# awards
# personal life
# early life and education
# awards and honours
# death
# further reading
# bibliography
# legacy
# filmography
# awards and recognitions
# awards and recognition
# works
# publications
# education
# awards and honors
# notes
# books
# life
# early life and background
# recognition
# honours
# political career
# discography
# selected bibliography
# family
# positions
# in popular culture
# early life and career
# life and career
# honours and awards
# positions held
# achievements
# controversies
# literary works
# controversy
# writings
# death and legacy
# honors and awards
# work
# literary career
# later life
# film career
# early life and training
# selected publications
# philanthropy
# honors
# early years
# selected works
# education and career
# acting career
# early life and family
# academic career
# awards and nominations
# research
# early career
# politics
# illness and death
# accolades
# ...
