# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

def out(ver,data):
    data.to_csv('final_result/PadmaAwards_v'+ver+'.csv')
    data.to_pickle('final_result/PadmaAwards_v'+ver+'.pickle')
    data.to_excel('final_result/PadmaAwards_v'+ver+'.xlsx')

# %%
old = pd.read_pickle('final_result/PadmaAwards_v2.pickle')
new = pd.read_pickle('final_result/PadmaAwards_v5.pickle')

# %%
new.head(3)
# Out:
#                                                         WikiLink  Padma Shri Year       Padma Shri State          Padma Shri Field Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By                                               Born  Birth Date Place of Birth                                               Died  Death Date            Place of Death Nationality Spouse Alma mater Institutions Other Awards including Padma         Occupation Election Year Posthumus     Page Id                                     image                                                Ref Recipients Telugu                                            Summary                                     Summary Telugu                                             career                                      career Telugu biography biography Telugu  \
# Recipients
# ...

# %%
old.head(4)
# Out:
#                  Recipients WikiLink  Padma Shri Year    Padma Shri State          Padma Shri Field Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By Born Birth Date Place of Birth Died Death Date Place of Death Nationality Spouse Alma mater Institutions Other Awards including Padma Occupation Election Year Posthumus  Page Id image  Ref           Recipients Telugu Summary Summary Telugu career career Telugu biography biography Telugu early life early life Telugu awards awards Telugu personal life personal life Telugu early life and education early life and education Telugu awards and honours awards and honours Telugu death death Telugu further reading further reading Telugu bibliography bibliography Telugu legacy legacy Telugu filmography filmography Telugu awards and recognitions awards and recognitions Telugu awards and recognition  \
# ...

# %%
# old.drop(columns=['Unnamed: 0'],inplace=True)
# list(old.columns)

# %%
old = old[old['Summary'].isnull()]

# %%
new.reset_index(inplace=True)
awards_temp = pd.concat([new,old])
out('5_02',awards_temp)

# %%
list(awards_temp.columns)
# Out:
# ['index',
#  'Recipients',
#  'WikiLink',
#  'Padma Shri Year',
#  'Padma Shri State',
#  'Padma Shri Field',
#  'Padma Shri Awarded By',
#  'Padma Bhushan Year',
#  'Padma Bhushan State',
#  'Padma Bhushan Field',
#  'Padma Bhushan Awarded By',
#  'Padma Vibhushan Year',
#  'Padma Vibhushan State',
#  'Padma Vibhushan Field',
#  'Padma Vibhushan Awarded By',
#  'Born',
#  'Birth Date',
#  'Place of Birth',
#  'Died',
#  'Death Date',
#  'Place of Death',
#  'Nationality',
#  'Spouse',
#  'Alma mater',
#  'Institutions',
#  'Other Awards including Padma',
#  'Occupation',
#  'Election Year',
#  'Posthumus',
#  'Page Id',
#  'image',
#  'Ref',
#  'Recipients Telugu',
#  'Summary',
#  'Summary Telugu',
#  'career',
#  'career Telugu',
#  'biography',
#  'biography Telugu',
#  'early life',
#  'early life Telugu',
#  'awards',
#  'awards Telugu',
#  'personal life',
#  'personal life Telugu',
#  'early life and education',
#  'early life and education Telugu',
#  'awards and honours',
# ...

# %%
padma_re_trans = ['Recipients', 'Padma Shri State', 'Padma Shri Field', 'Padma Shri Awarded By', 'Padma Bhushan State', 'Padma Bhushan Field', 'Padma Bhushan Awarded By', 'Padma Vibhushan State', 'Padma Vibhushan Field','Padma Vibhushan Awarded By']
to_kaggle = awards_temp[padma_re_trans]
to_kaggle.shape
# Out:
# (4420, 10)

# %%
to_kaggle.reset_index(inplace=True)

# %%
out('5_03',to_kaggle)

# %%
kg = pd.read_pickle('final_result/PadmaAwards_v5_05.pickle')
aw = pd.read_pickle('final_result/PadmaAwards_v5_02.pickle')
kg.drop(columns=['Unnamed: 0','index'],inplace=True)
aw.drop(columns=['index'],inplace=True)
aw.set_index('Recipients',inplace=True)
kg.set_index('Recipients',inplace=True)

# %%
aw['Padma Shri State Tel'] = kg['Padma Shri State Tel'] 
aw['Padma Shri Field Tel'] = kg['Padma Shri Field Tel'] 
aw['Padma Shri Awarded By Tel'] = kg['Padma Shri Awarded By Tel'] 
aw['Padma Bhushan State Tel'] = kg['Padma Bhushan State Tel'] 
aw['Padma Bhushan Field Tel'] = kg['Padma Bhushan Field Tel'] 
aw['Padma Bhushan Awarded By Tel'] = kg['Padma Bhushan Awarded By Tel'] 
aw['Padma Vibhushan State Tel'] = kg['Padma Vibhushan State Tel'] 
aw['Padma Vibhushan Field Tel'] = kg['Padma Vibhushan Field Tel'] 
aw['Padma Vibhushan Awarded By Tel'] = kg['Padma Vibhushan Awarded By Tel'] 
aw.tail()
# Out:
#                                                                   WikiLink  Padma Shri Year    Padma Shri State         Padma Shri Field      Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By                                               Born Birth Date                       Place of Birth Died Death Date Place of Death Nationality Spouse Alma mater Institutions Other Awards including Padma Occupation Election Year Posthumus     Page Id image  Ref               Recipients Telugu Summary Summary Telugu career career Telugu biography biography Telugu early life early life Telugu awards awards Telugu personal life personal life Telugu early life and education early life and education Telugu awards and honours awards and honours Telugu death death Telugu further reading further reading Telugu bibliography bibliography Telugu legacy  \
# ...

# %%
out('6',aw)

# %%
aw = pd.read_pickle('final_result/PadmaAwards_v6.pickle')

# %%
aw.sort_index(inplace=True)
aw.head(23)
# Out:
#                                                                          WikiLink  Padma Shri Year       Padma Shri State          Padma Shri Field     Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State       Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year  Padma Vibhushan State    Padma Vibhushan Field Padma Vibhushan Awarded By                                               Born  Birth Date                                     Place of Birth                                               Died  Death Date                              Place of Death Nationality                   Spouse                                         Alma mater                                       Institutions                       Other Awards including Padma                                   Occupation Election Year Posthumus     Page Id                                              image                                                Ref             Recipients Telugu  \
# ...
