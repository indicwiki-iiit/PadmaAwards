# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import sweetviz as sv

def out(ver,data,sw=False):
    data.to_csv('output/Awards'+ver+'.csv')
    data.to_pickle('output/Awards'+ver+'.pickle')
    data.to_excel('output/Awards'+ver+'.xlsx')
    if sw:
        sv.analyze(data).show_html('output/Awards'+ver+'.html',pairwise_analysis='off')

# %%
awards = pd.read_csv('renders/renders_awards_v4_Kaggle_out.csv',low_memory=False)
# def merge_def(col,awards):
    # print('*'*30+'Translate Google '+col+'*'*30)
    # awards[col+' Telugu'] = np.nan
# d2 = {}
# for k,v in enumerate(awards.columns):
#     d2[v] = k
    # awards2 = awards.copy()
    # awards2 = awards2[['Recipients',col,col+' Telugu']]
    # out('6_'+str(d2[col])+col,awards2)
# print('6_'+str(d2[col])+col)
    # print('$'*30+'FIN :: Translate Google '+ col +'$'*30)

# %%
awards.drop(columns=['Unnamed: 0.1'],inplace=True)

# %%
d = {}
for i in awards.columns:
    if i not in d:
        d[i] = sum(~pd.isna(awards[i])) 
k = list(sorted(d.items(), key=lambda x:x[1],reverse=True))
new_lis = [ i[0] for i in k]
awards = awards[new_lis]
# awards.head(4)
new_lis
dont_want = ['Unnamed: 0.1','Unnamed: 0','index','Recipients', 'Recipients Telugu','references','see also','external links', 'gallery',]
Final = ['Recipients', 'Recipients Telugu']
# d2 = {}
# for k,v in enumerate(awards.columns):
#     d2[v] = k
lis_r = []
for i in new_lis:
    if i not in dont_want:
        lis_r.append(i)
        # print('6_'+str(d2[i])+i)
lis_r
# Out:
# ['Summary',
#  'career',
#  'biography',
#  'early life',
#  'awards',
#  'personal life',
#  'early life and education',
#  'awards and honours',
#  'death',
#  'further reading',
#  'bibliography',
#  'legacy',
#  'filmography',
#  'awards and recognitions',
#  'awards and recognition',
#  'works',
#  'publications',
#  'education',
#  'awards and honors',
#  'notes',
#  'books',
#  'life',
#  'early life and background',
#  'recognition',
#  'honours',
#  'political career',
#  'discography',
#  'selected bibliography',
#  'family',
#  'positions',
#  'in popular culture',
#  'early life and career',
#  'life and career',
#  'honours and awards',
#  'positions held',
#  'achievements',
#  'controversies',
#  'literary works',
#  'controversy',
#  'writings',
#  'death and legacy',
#  'honors and awards',
#  'work',
#  'literary career',
#  'later life',
#  'film career',
#  'early life and training',
#  'selected publications',
#  'philanthropy',
#  'honors',
#  'early years',
# ...

# %%
awards = pd.read_csv('renders/renders_awards_v4_Kaggle_out.csv',low_memory=False)
d2 = {}
for k,v in enumerate(awards.columns):
    d2[v] = k
fin_lis = ['Recipients', 'Recipients Telugu']
for i in lis_r:
    i_tel = i+' Telugu'
    awards[i_tel] = np.nan 
    file_name = '6_'+str(d2[i])+i
    try:
        temp_df = pd.read_pickle('renders/kaggle_renders/translate_awards_v'+file_name+'_Kaggle_out.pickle')
        awards[i_tel] =  temp_df[i_tel]
        fin_lis.append(i)
        fin_lis.append(i_tel)
    except Exception as e:
        print(e)
awards = awards[fin_lis]
awards.head(10)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_25512\1802484410.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   awards[i_tel] = np.nan
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_25512\1802484410.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   awards[i_tel] = np.nan
# ...

# %%
out('_wikipedia_data',awards)
# Out:
# [Summarizing dataframe]                      |          | [  0%]   00:00 -> (02:05 left)
# PAIRWISE CALCULATION LENGTH WARNING: There are 358 features in this dataframe and the 'pairwise_analysis' parameter is set to 'auto'.
# Pairwise analysis is exponential in length: 358 features will cause ~128164 pairs to be evaluated, which could take a long time.
#
# You must call the function with the parameter pairwise_analysis='on' or 'off' to explicitly select desired behavior.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\LEGION\Documents\padmaAwards\src\Clean_05_integration.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LEGION/Documents/padmaAwards/src/Clean_05_integration.ipynb#ch0000007?line=0'>1</a> out('_wikipedia_data',awards,sw=True)
#
# ...

# %%
sv.analyze(awards,pairwise_analysis='off').show_html('output/Awards_wikipedia_data.html')
# Out:
# Feature: notes                               |█▏        | [ 11%]   00:00 -> (00:04 left)C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: notes Telugu                        |█▏        | [ 12%]   00:01 -> (00:04 left)C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 3118 (\N{TELUGU LETTER MA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# ...
